# %% [markdown]
# # 🎬 AutoClipper Studio - Google Colab Cloud GPU Runner
#
# Welcome to **AutoClipper Studio Cloud Edition**! Run AI-powered 9:16 vertical video clipping with **Free NVIDIA T4 / A100 GPUs** on Google Colab.
#
# ### 🚀 Instructions:
# 1. **Set Runtime to GPU**: Go to `Runtime` -> `Change runtime type` -> Select `T4 GPU` (or A100 GPU).
# 2. **Run Cell 1**: Check GPU hardware & install system `ffmpeg`.
# 3. **Run Cell 2**: Install required Python packages.
# 4. **Run Cell 3**: Launch the Web App with public URL (`https://xxxx.gradio.live`). Open the public URL in your browser to process videos, preview clips, and download ZIP archives!

# %%
# 1. GPU Check & Install System FFmpeg
# !nvidia-smi
# !apt-get update -qq && apt-get install -y ffmpeg

# %%
# 2. Install Python Dependencies
# !pip install -q gradio ultralytics opencv-python-headless yt-dlp openai-whisper torch torchvision

# %%
# 3. Launch AutoClipper Studio Web UI
# Note: --share creates a free public URL (zero ngrok required!)
# !python web_app.py --share
